# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../src")
sys.path.append("../data/embeddings")
import classifier
import debias
#import debias_old as debias
import gensim
import codecs
import json
from gensim.models.keyedvectors import Word2VecKeyedVectors
from gensim.models import KeyedVectors
import numpy as np
import random
import sklearn
from sklearn import model_selection
from sklearn import cluster
from sklearn import metrics
from sklearn.manifold import TSNE
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import SGDClassifier, Perceptron, LogisticRegression, PassiveAggressiveClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
import scipy
from scipy import linalg
from scipy.stats.stats import pearsonr
import tqdm
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['agg.path.chunksize'] = 10000
from sklearn.utils import shuffle

#import warnings
#warnings.filterwarnings("ignore")
# Out:
# /tmp/ipykernel_51056/1012197530.py:27: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
def tsne(vecs, labels, title="", ind2label = None, words = None, metric = "l2"):

  tsne = TSNE(n_components=2)#, angle = 0.5, perplexity = 20)
  vecs_2d = tsne.fit_transform(vecs)
  label_names = sorted(list(set(labels.tolist())))
  num_labels = len(label_names)

  names = sorted(set(labels.tolist()))

  plt.figure(figsize=(6, 5))
  colors = "red", "blue"
  for i, c, label in zip(sorted(set(labels.tolist())), colors, names):
     plt.scatter(vecs_2d[labels == i, 0], vecs_2d[labels == i, 1], c=c,
                label=label if ind2label is None else ind2label[label], alpha = 0.3, marker = "s" if i==0 else "o")
     plt.legend(loc = "upper right")

  plt.title(title)
  plt.savefig("race_embeddings.{}.png".format(title), dpi=600)
  plt.show()
  return vecs_2d

# %% [markdown]
# ### Data loading & processing

# %%
def load_word_vectors(fname):
    
    model = KeyedVectors.load_word2vec_format(fname, binary=False)
    vecs = model.vectors
    words = list(model.vocab.keys())
    return model, vecs, words

def project_on_gender_subspaces(gender_vector, model: Word2VecKeyedVectors, n = 2500):
    
    group1 = model.similar_by_vector(gender_vector, topn = n, restrict_vocab=None)
    group2 = model.similar_by_vector(-gender_vector, topn = n, restrict_vocab=None)
    
    all_sims = model.similar_by_vector(gender_vector, topn = len(model.vectors), restrict_vocab=None)
    eps = 0.03
    idx = [i for i in range(len(all_sims)) if abs(all_sims[i][1]) < eps]
    samp = set(np.random.choice(idx, size = n))
    neut = [s for i,s in enumerate(all_sims) if i in samp]
    return group1, group2, neut

def get_vectors(word_list: list, model: Word2VecKeyedVectors):
    
    vecs = []
    for w in word_list:
        
        vecs.append(model[w])
    
    vecs = np.array(vecs)

    return vecs
    
def get_bias_by_neighbors(model, v, gender_direction, topn): 
    
    neighbors = model.similar_by_vector(v, topn = topn) 
    neighbors_words = [n for n, _ in neighbors]
    
    #bias = len([n for n in neighbors_words if n in gendered_words])
    bias = len([n for n in neighbors_words if model.cosine_similarities(model[n], [gender_direction])[0] > 0])
    bias /= (1.*topn)
    return bias


def save_in_word2vec_format(vecs: np.ndarray, words: np.ndarray, fname: str):


    with open(fname, "w", encoding = "utf-8") as f:

        f.write(str(len(vecs)) + " " + "300" + "\n")
        for i, (v,w) in tqdm.tqdm_notebook(enumerate(zip(vecs, words))):

            vec_as_str = " ".join([str(x) for x in v])
            f.write(w + " " + vec_as_str + "\n")

# %% [markdown]
# ### Load word vectors

# %%
# 150k top vectors (with gender-typical words) - used for training

model, vecs, words = load_word_vectors(fname = "../data/embeddings/vecs.filtered.txt")

# only gendered vectors

model_gendered, _, _ = load_word_vectors(fname = "../data/embeddings/vecs.gendered.txt")

# %% [markdown]
# ### Collect biased words

# %%
num_vectors_per_class = 7500

by_pca = False
if by_pca:
    pairs = [("male", "female"), ("masculine", "feminine"), ("he", "she"), ("him", "her")]
    gender_vecs = [model[p[0]] - model[p[1]] for p in pairs]
    pca = PCA(n_components=1)
    pca.fit(gender_vecs)
    gender_direction = pca.components_[0]
    
else:
    gender_direction = model["british"]-model["indian"] 


gender_unit_vec = gender_direction/np.linalg.norm(gender_direction)
masc_words_and_scores, fem_words_and_scores, neut_words_and_scores = project_on_gender_subspaces(gender_direction, model, n = num_vectors_per_class)

masc_words, masc_scores = list(zip(*masc_words_and_scores))
neut_words, neut_scores = list(zip(*neut_words_and_scores))
fem_words, fem_scores = list(zip(*fem_words_and_scores))
masc_vecs, fem_vecs = get_vectors(masc_words, model), get_vectors(fem_words, model)
neut_vecs = get_vectors(neut_words, model)

n = min(3000, num_vectors_per_class)
all_significantly_biased_words = masc_words[:n] + fem_words[:n]
all_significantly_biased_vecs =  np.concatenate((masc_vecs[:n], fem_vecs[:n]))
all_significantly_biased_labels = np.concatenate((np.ones(n, dtype = int),
                                                  np.zeros(n, dtype = int)))

all_significantly_biased_words, all_significantly_biased_vecs, all_significantly_biased_labels = sklearn.utils.shuffle(
all_significantly_biased_words, all_significantly_biased_vecs, all_significantly_biased_labels)
#print(np.random.choice(masc_words, size = 75))
print("TOP British")
print(masc_words[:50])
#print("LAST MASC")
#print(masc_words[-120:])
print("-------------------------")
#print(np.random.choice(fem_words, size = 75))
print("TOP Indian")
print(fem_words[:50])
#print("LAST FEM")
#print(fem_words[-120:])
print("-------------------------")
#print(np.random.choice(neut_words, size = 75))
print(neut_words[:50])
# Out:
# TOP British
# ('british', 'britain', 'columbians', 'pathé', 'dinard', 'easyjet', 'smithers', 'halifax', 'britpop', 'falklands', 'bhf', 'northumbria', 'tories', 'flanders', 'lingus', 'flybe', 'beazley', 'liege', 'centrica', 'bbc', 'normandy', 'hbos', 'nonconformist', 'stromness', 'brits', 'murdoch', 'britsh', 'cbe', 'gaulle', 'namur', 'ostend', 'davies', 'slendertone', 'kerrang', 'brit', 'gaumont', 'cbc', 'runciman', 'rhys', 'frenchies', 'archons', 'scotsman', 'dimbleby', 'ryanair', 'raf', 'bvi', 'stannis', 'redcoat', 'costello', 'menzies')
# -------------------------
# TOP Indian
# ('indian', 'ganesh', 'hopi', 'masala', 'chaat', 'mallu', 'hindu', 'navajo', 'desi', 'gaur', 'manjula', 'palak', 'tiwari', 'pooja', 'saree', 'krishnan', 'nath', 'chana', 'bhat', 'shankar', 'india', 'aloo', 'tabla', 'choli', 'kannada', 'sarees', 'rajasthani', 'mamta', 'ganesha', 'sitar', 'oriya', 'jain', 'dutta', 'rahul', 'prasad', 'rasam', 'marathi', 'kurti', 'krishna', 'sharma', 'bollywood', 'dhaba', 'shraddha', 'telugu', 'pandit', 'agarwal', 'tulsi', 'aunties', 'puja', 'kerala')
# -------------------------
# ('boxing', 'caselaw', 'microarchitecture', 'nasp', 'er', 'unsc', 'aka', 'naismith', 'ausstellung', 'availibility', 'divisible', 'destry', 'outgrown', 'zippo', 'netminder', 'sysco', 'crib', 'confide', 'yuengling', 'hazan', 'foix', 'longplay', 'autocomplete', 'utilitarianism', 'amthank', 'ocw', 'speck', 'histonet', 'multimeter', 'robbing', 'engage', 'disrespectful', 'lyse', 'belfer', 'biocontrol', 'herzliya', 'ee', 'aforementioned', 'snuggie', 'barebone', 'adeline', 'outdrive', 'kord', 'westies', 'gynecologist', 'dpp', 'orderby', 'mellotron', 'milloy', 'reinvigorating')

# %%
print(masc_scores[:10])
print(masc_scores[-10:])
print(neut_scores[:10])
# Out:
# (0.4159376621246338, 0.34573104977607727, 0.3429659903049469, 0.3064081370830536, 0.28061842918395996, 0.2747316360473633, 0.27216029167175293, 0.271121084690094, 0.26970553398132324, 0.26809027791023254)
# (0.10317684710025787, 0.10316900163888931, 0.103166863322258, 0.1031666100025177, 0.10315892100334167, 0.10315825790166855, 0.10314655303955078, 0.10314621776342392, 0.10314011573791504, 0.10313938558101654)
# (0.029999587684869766, 0.029997635632753372, 0.029970355331897736, 0.029964469373226166, 0.029953990131616592, 0.029951106756925583, 0.029950935393571854, 0.02994643524289131, 0.029928483068943024, 0.02991759590804577)

# %% [markdown]
# ### Perform train-dev-test split

# %%
random.seed(0)
np.random.seed(0)

X = np.concatenate((masc_vecs, fem_vecs, neut_vecs), axis = 0)
#X = (X - np.mean(X, axis = 0, keepdims = True)) / np.std(X, axis = 0)
y_masc = np.ones(masc_vecs.shape[0], dtype = int)
y_fem = np.zeros(fem_vecs.shape[0], dtype = int)
y_neut = -np.ones(neut_vecs.shape[0], dtype = int)
#y = np.concatenate((masc_scores, fem_scores, neut_scores))#np.concatenate((y_masc, y_fem))
y = np.concatenate((y_masc, y_fem, y_neut))
X_train_dev, X_test, y_train_dev, Y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 0)
X_train, X_dev, Y_train, Y_dev = sklearn.model_selection.train_test_split(X_train_dev, y_train_dev, test_size = 0.3, random_state = 0)
print("Train size: {}; Dev size: {}; Test size: {}".format(X_train.shape[0], X_dev.shape[0], X_test.shape[0]))
# Out:
# Train size: 10776; Dev size: 4619; Test size: 6598

# %% [markdown]
# ### Debias

# %%
gender_clf = LinearSVC
#gender_clf = SGDClassifier
#gender_clf = LogisticRegression
#gender_clf = LinearDiscriminantAnalysis
#gender_clf = Perceptron

params_svc = {'fit_intercept': False, 'class_weight': None, "dual": False, 'random_state': 0}
params_sgd = {'fit_intercept': False, 'class_weight': None, 'max_iter': 1000, 'random_state': 0}
params = params_svc
#params = {'loss': 'hinge', 'n_jobs': 16, 'penalty': 'l2', 'max_iter': 2500, 'random_state': 0}
#params = {}
n = 35
min_acc = 0
is_autoregressive = True
dropout_rate = 0

P, rowspace_projs, Ws = debias.get_debiasing_projection(gender_clf, params, n, 300, is_autoregressive, min_acc,
                                    X_train, Y_train, X_dev, Y_dev,
                                       Y_train_main=None, Y_dev_main=None, 
                                        by_class = False, dropout_rate = dropout_rate)
# Out:
# iteration: 34, accuracy: 0.3377354405715523: 100%|███| 35/35 [00:37<00:00,  1.06s/it]

# %%
np.save("P.race.glove.dim=300.iters=35.npy", P)

# %% [markdown]
# ### Test the quality of the debiasing.

# %% [markdown]
# #### Perform t-sne

# %%
def perform_purity_test(vecs, k, labels_true):
        np.random.seed(0)
        clustering = sklearn.cluster.KMeans(n_clusters = k)
        clustering.fit(vecs)
        labels_pred = clustering.labels_
        score = sklearn.metrics.homogeneity_score(labels_true, labels_pred)
        return score

def compute_v_measure(vecs, labels_true, k=2):
    
        np.random.seed(0)
        clustering = sklearn.cluster.KMeans(n_clusters = k)
        clustering.fit(vecs)
        labels_pred = clustering.labels_
        return sklearn.metrics.v_measure_score(labels_true, labels_pred)
    

# remove neutral class, keep only male and female biased

X_dev = X_dev[Y_dev != -1]
X_train = X_train[Y_train != -1]
X_test = X_test[Y_test != -1]


Y_dev = Y_dev[Y_dev != -1]
Y_train = Y_train[Y_train != -1]
Y_test = Y_test[Y_test != -1]


M =  2000
ind2label =  {1: "British-biased", 0: "Indian-biased"}
#tsne_before = tsne(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M], title = "Original (t=0)", ind2label =ind2label )
tsne_before = tsne(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M], title = "Original (t=0)", ind2label =ind2label )


X_dev_cleaned = (P.dot(X_dev.T)).T 
X_test_cleaned = (P.dot(X_test.T)).T 
X_trained_cleaned = (P.dot(X_train.T)).T 
all_significantly_biased_cleaned = P.dot(all_significantly_biased_vecs.T).T

#tsne_after = tsne_by_gender(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M], title = "Projected (t = {})".format(n))
tsne_after = tsne(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M], title = "Projected (t={})".format(n), ind2label =ind2label )

#tsne_projection = tsne_by_gender(all_biased_cleaned, all_significantly_biased_labels,title = "after (all)", words = all_significantly_biased_words)

print("V-measure-before (TSNE space): {}".format(compute_v_measure(tsne_before, all_significantly_biased_labels[:M])))
print("V-measure-after (TSNE space): {}".format(compute_v_measure(tsne_after, all_significantly_biased_labels[:M])))

#print("V-measure-before (original space): {}".format(compute_v_measure(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M]), k = 2))
#print("V-measure-after (original space): {}".format(compute_v_measure(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M]), k = 2))
print("V-measure-before (original space): {}".format(compute_v_measure(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M]), k = 2))
print("V-measure-after (original space): {}".format(compute_v_measure(X_test_cleaned[:M], Y_test[:M]), k = 2))

rank_before = np.linalg.matrix_rank(X_train)
rank_after = np.linalg.matrix_rank(X_trained_cleaned)
print("Rank before: {}; Rank after: {}".format(rank_before, rank_after))
# Out:
# /Users/evar/mambaforge/envs/null_space/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/evar/mambaforge/envs/null_space/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/evar/mambaforge/envs/null_space/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# V-measure-before (TSNE space): 0.857197413399542
# V-measure-after (TSNE space): 0.017214659634258334
# V-measure-before (original space): 1.0
# /Users/evar/mambaforge/envs/null_space/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# V-measure-after (original space): 0.00010885281370976269
# Rank before: 300; Rank after: 290

# %%
for t in [1,3,12,18,25,35]:
    p = debias.get_projection_to_intersection_of_nullspaces(rowspace_projs[:t], 300)
    tsne_after = tsne(p.dot(all_significantly_biased_vecs[:M].T).T, all_significantly_biased_labels[:M], title = "Projected (t={})".format(t), ind2label =ind2label )

# %% [markdown]
# ## increase the race component (not in the paper)

# %%
for word in ['curry', 'london', 'dehli', 'persian', "quality", "mathematics", "red", "bag", "draft", "fashion", "nurse", "teacher",
            "talk", "book"]:
    v_word = model[word]
    P_rowspace = debias.get_rowspace_projection(Ws[1]) #np.eye(P.shape[0]) - P
    P_rowspace = np.eye(P.shape[0]) - P


    v_null, v_row = P.dot(v_word), P_rowspace.dot(v_word)
    #v_row = np.where(v_row < 0, v_row, 0.0)
    for alpha in [-1,3]: #np.linspace(-1, 3, 100):
    
        v = v_row * (1 + alpha) + v_null * 1.0
        u, _ =  list(zip(*model.similar_by_vector((v/np.linalg.norm(v))*np.linalg.norm(v_word), topn = 100, restrict_vocab=None)))
        print("word={}; alpha= {}; neighbors: {}".format(word, alpha, u[:8]))
        print("------------------")
    print("========================================")
# Out:
# word=curry; alpha= -1; neighbors: ('curry', 'chilli', 'sauce', 'chicken', 'rice', 'fried', 'soup', 'spicy')
# ------------------
# word=curry; alpha= 3; neighbors: ('curry', 'rice', 'indian', 'chicken', 'soup', 'chili', 'cook', 'dish')
# ------------------
# ========================================
# word=london; alpha= -1; neighbors: ('london', 'uk', 'edinburgh', 'sydney', 'manchester', 'leeds', 'delhi', 'berlin')
# ------------------
# word=london; alpha= 3; neighbors: ('london', 'uk', 'britain', 'england', 'edinburgh', 'british', 'glasgow', 'manchester')
# ------------------
# ========================================
# word=dehli; alpha= -1; neighbors: ('dehli', 'delhi', 'poona', 'bombay', 'banglore', 'calcutta', 'zeland', 'lucknow')
# ------------------
# word=dehli; alpha= 3; neighbors: ('dehli', 'delhi', 'chandni', 'banglore', 'lucknow', 'dilli', 'guwahati', 'poona')
# ------------------
# ========================================
# word=persian; alpha= -1; neighbors: ('persian', 'turkish', 'iranian', 'arabic', 'farsi', 'arabian', 'tabriz', 'persians')
# ------------------
# word=persian; alpha= 3; neighbors: ('persian', 'arabic', 'turkish', 'oriental', 'arabian', 'indian', 'chinese', 'iranian')
# ------------------
# ========================================
# word=quality; alpha= -1; neighbors: ('quality', 'excellent', 'exceptional', 'best', 'high', 'good', 'better', 'highest')
# ------------------
# word=quality; alpha= 3; neighbors: ('quality', 'high', 'excellent', 'exceptional', 'provide', 'superior', 'better', 'ensure')
# ------------------
# ========================================
# word=mathematics; alpha= -1; neighbors: ('mathematics', 'math', 'mathematical', 'physics', 'algebra', 'science', 'maths', 'biology')
# ------------------
# word=mathematics; alpha= 3; neighbors: ('mathematics', 'math', 'mathematical', 'physics', 'science', 'algebra', 'biology', 'teaching')
# ------------------
# ========================================
# word=red; alpha= -1; neighbors: ('red', 'blue', 'purple', 'yellow', 'white', 'pink', 'green', 'black')
# ------------------
# word=red; alpha= 3; neighbors: ('red', 'blue', 'white', 'green', 'yellow', 'orange', 'black', 'purple')
# ------------------
# ========================================
# word=bag; alpha= -1; neighbors: ('bag', 'bags', 'tote', 'backpack', 'purse', 'handbag', 'pouch', 'wallet')
# ------------------
# word=bag; alpha= 3; neighbors: ('bag', 'bags', 'purse', 'tote', 'pouch', 'handbag', 'backpack', 'wallet')
# ------------------
# ========================================
# word=draft; alpha= -1; neighbors: ('draft', 'drafted', 'drafts', 'nfl', 'proposal', 'roster', 'drafting', 'rookie')
# ------------------
# word=draft; alpha= 3; neighbors: ('draft', 'drafted', 'drafts', 'nfl', 'nba', 'pick', 'signed', 'picks')
# ------------------
# ========================================
# word=fashion; alpha= -1; neighbors: ('fashion', 'fashionable', 'fashions', 'designer', 'vogue', 'style', 'dress', 'clothing')
# ------------------
# word=fashion; alpha= 3; neighbors: ('fashion', 'style', 'fashionable', 'dress', 'jewelry', 'clothing', 'designer', 'fashions')
# ------------------
# ========================================
# word=nurse; alpha= -1; neighbors: ('nurse', 'nurses', 'nursing', 'rn', 'physician', 'practitioner', 'therapist', 'doctor')
# ------------------
# word=nurse; alpha= 3; neighbors: ('nurse', 'nurses', 'nursing', 'physician', 'rn', 'doctor', 'therapist', 'care')
# ------------------
# ========================================
# word=teacher; alpha= -1; neighbors: ('teacher', 'teachers', 'teaching', 'student', 'school', 'tutor', 'instructor', 'classroom')
# ------------------
# word=teacher; alpha= 3; neighbors: ('teacher', 'teachers', 'student', 'teaching', 'school', 'classroom', 'instructor', 'students')
# ------------------
# ========================================
# word=talk; alpha= -1; neighbors: ('talk', 'talking', 'speak', 'discuss', 'tell', 'talks', 'know', 'talked')
# ------------------
# word=talk; alpha= 3; neighbors: ('talk', 'talking', 'discuss', 'speak', 'talked', 'tell', 'know', 'conversation')
# ------------------
# ========================================
# word=book; alpha= -1; neighbors: ('book', 'books', 'author', 'read', 'reading', 'story', 'ebook', 'paperback')
# ------------------
# word=book; alpha= 3; neighbors: ('book', 'books', 'author', 'reading', 'paperback', 'read', 'writing', 'history')
# ------------------
# ========================================

# %% [markdown]
# #### Train linear & nonlinear classifiers for race prediction.

# %%
"""
nonlinear_clf = SVC(kernel = "rbf")
print("Before, rbf-svm:")
nonlinear_clf.fit(X_train, Y_train)
print(nonlinear_clf.score(X_dev, Y_dev))

""" 
print("Before, linear:")
linear_clf = LinearSVC(dual=False, max_iter = 1500)
linear_clf.fit(X_train, Y_train)
print(linear_clf.score(X_test, Y_test))

print("After, linear:")
linear_clf = LinearSVC(dual=False, max_iter = 1500)
linear_clf.fit(X_trained_cleaned, Y_train)
print(linear_clf.score(X_test_cleaned, Y_test))

print("After, rbf-svm:")
nonlinear_clf = SVC(kernel = "rbf")
nonlinear_clf.fit(X_trained_cleaned, Y_train)
print(nonlinear_clf.score(X_dev_cleaned, Y_dev))

print("After, mlp:")
nonlinear_clf = MLPClassifier(hidden_layer_sizes = 256, activation = "relu")

nonlinear_clf.fit(X_trained_cleaned, Y_train)
print(nonlinear_clf.score(X_dev_cleaned, Y_dev))
# Out:
# Before, linear:
# 1.0
# After, linear:
# 0.5018918317382595
# After, rbf-svm:
# 0.8220897395669909
# After, mlp:
# 0.7988704110448698

# %% [markdown]
# The information is still recoverable by nonlinear model.

# %% [markdown]
# #### project on the race direction

# %%
masc_vecs_cleaned = P.dot(masc_vecs.T).T
fem_vecs_cleaned = P.dot(fem_vecs.T).T

print("british-bias-before: {}".format(masc_vecs.dot(gender_unit_vec).mean()))
print("british-bias-after: {}".format(masc_vecs_cleaned.dot(gender_unit_vec.dot(P)).mean()))
print("indian-bias-before: {}".format(fem_vecs.dot(gender_unit_vec).mean()))
print("indian-bias-after: {}".format(fem_vecs_cleaned.dot(gender_unit_vec.dot(P)).mean()))
# Out:
# british-bias-before: 0.8588877320289612
# british-bias-after: -0.039335549535533476
# indian-bias-before: -1.0786176919937134
# indian-bias-after: -0.04327249669925191

# %% [markdown]
# #### calculate the similarity matrix before and after

# %%
def get_distance_matrix(vecs: np.ndarray):

  distances = sklearn.metrics.pairwise_distances(vecs, vecs, metric="cosine")
  return distances

def plot_distance(distance_before, distance_after):

    idx = distance_before < 0.75 # we are only interested in the relatively close words

    distance_before = distance_before.copy()[idx]
    distance_after = distance_after.copy()[idx]
    
    chosen = np.random.rand(len(distance_before)) < 0.01
    before = distance_before[chosen]
    after = distance_after[chosen]
    plt.plot(before, after, linestyle="None", marker = "*", alpha = 0.1)
    plt.xlabel("distnace before")
    plt.ylabel("distance after")

    plt.show()
    print("Correlation: {}".format(pearsonr(before, after)[0]))
    
def plot_similarity_change_vs_original_bias(bias_before, distance_before, distance_after):

    K = 50
    most_similar_idx_before = distance_before.argsort(axis = 0)[:K].T
    most_similar_idx_after = distance_after.argsort(axis = 0)[:K].T
    data = []
    
    for i, (bias, dis_before, dis_after) in enumerate(tqdm.tqdm_notebook(zip(bias_before, distance_before, distance_after), ascii = True, total = len(bias_before))):
        
        idx_before = set(most_similar_idx_before[i].tolist())
        idx_after = set(most_similar_idx_after[i].tolist())
        intersection = (most_similar_idx_before[i] == most_similar_idx_after[i]).sum() 
        intersection = idx_before.intersection(idx_after)
        data.append((abs(bias), 1 - len(intersection)/K))
        #data.append((abs(bias), 1 - intersection/K))
        
    plt.xlabel("change in similarity (% of of top-{}-similar that changed)".format(K))
    plt.ylabel("bias before")
    biases, sims = zip(*data)    
    plt.plot(sims, biases, linestyle="None", marker = "*", alpha = 0.1)

    plt.show()
    print("Correlation: {}".format(pearsonr(biases, sims)[0]))

# %%
vecs_cleaned = (P.dot(vecs.T)).T
save_in_word2vec_format(vecs_cleaned, words, "../data/embeddings/vecs.150k.cleaned_race.txt")
model_cleaned, _, _ = load_word_vectors(fname = "../data/embeddings/vecs.150k.cleaned_race.txt")
# Out:
# /tmp/ipykernel_51056/1758568085.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, (v,w) in tqdm.tqdm_notebook(enumerate(zip(vecs, words))):
# 0it [00:00, ?it/s]

# %% [markdown]
# #### calcualte the similarity of female-stereotyped words to 'girlish', before and after

# %%
for w in ["curry", 'rice', 'temple', 'dehli', 'london', 'taxi', 'ceo', 'engineer', 'nurse', 'monk', 'programmer', 'immigrant', 'brown', 'poor']:
    k = 5000

    random_fem_words = np.random.choice(fem_words, size = k)
    sim_to_girlish_before = [model.similarity(w,w2) for w2 in random_fem_words]
    sim_to_girlish_after = [model_cleaned.similarity(w,w2) for w2 in random_fem_words]

    print("Similarity of Indian-stereotyped words to '{}' before: {}; similarity after: {}".format(w, np.mean(sim_to_girlish_before), np.mean(sim_to_girlish_after)))


    random_masc_words = np.random.choice(masc_words, size = k)
    sim_to_girlish_before = [model.similarity(w,w2) for w2 in random_masc_words]
    sim_to_girlish_after = [model_cleaned.similarity(w,w2) for w2 in random_masc_words]

    print("Similarity of British-stereotyped words to '{}' before: {}; similarity after: {}".format(w, np.mean(sim_to_girlish_before), np.mean(sim_to_girlish_after)))
    print("")
# Out:
# Similarity of Indian-stereotyped words to 'curry' before: 0.05863908678293228; similarity after: 0.002527615986764431
# Similarity of British-stereotyped words to 'curry' before: -0.006475224159657955; similarity after: -0.00029954308411106467
#
# Similarity of Indian-stereotyped words to 'rice' before: 0.03810920566320419; similarity after: -0.0018851036438718438
# Similarity of British-stereotyped words to 'rice' before: -0.0068689254112541676; similarity after: -0.00110248988494277
#
# Similarity of Indian-stereotyped words to 'temple' before: 0.06377206742763519; similarity after: 0.0016594664193689823
# Similarity of British-stereotyped words to 'temple' before: -0.003944252617657185; similarity after: -0.0016500824131071568
#
# Similarity of Indian-stereotyped words to 'dehli' before: 0.09213235974311829; similarity after: 0.001251394976861775
# Similarity of British-stereotyped words to 'dehli' before: 0.014037316665053368; similarity after: -0.00021528730576392263
#
# Similarity of Indian-stereotyped words to 'london' before: -0.006191742606461048; similarity after: 0.0027095729019492865
# Similarity of British-stereotyped words to 'london' before: 0.07619571685791016; similarity after: 0.0011953396024182439
#
# Similarity of Indian-stereotyped words to 'taxi' before: 0.010049558244645596; similarity after: 0.0001414645230397582
# Similarity of British-stereotyped words to 'taxi' before: 0.020822444930672646; similarity after: 0.0011520811822265387
#
# Similarity of Indian-stereotyped words to 'ceo' before: 0.02499639242887497; similarity after: -0.0009853014489635825
# Similarity of British-stereotyped words to 'ceo' before: 0.03330010548233986; similarity after: 0.0022497547324746847
#
# Similarity of Indian-stereotyped words to 'engineer' before: 0.0006189225241541862; similarity after: 0.0009179452899843454
# Similarity of British-stereotyped words to 'engineer' before: 0.018084825947880745; similarity after: 0.0020562619902193546
#
# Similarity of Indian-stereotyped words to 'nurse' before: -0.0007903064833953977; similarity after: 0.0018111204262822866
# Similarity of British-stereotyped words to 'nurse' before: 0.015297927893698215; similarity after: 0.00021253399609122425
#
# Similarity of Indian-stereotyped words to 'monk' before: 0.021266832947731018; similarity after: -0.0009928708896040916
# Similarity of British-stereotyped words to 'monk' before: 0.021475017070770264; similarity after: 0.0006683277897536755
#
# Similarity of Indian-stereotyped words to 'programmer' before: -0.005875621922314167; similarity after: 0.0013614209601655602
# Similarity of British-stereotyped words to 'programmer' before: 0.01399864163249731; similarity after: 0.0020286617800593376
#
# Similarity of Indian-stereotyped words to 'immigrant' before: 0.004393375013023615; similarity after: 0.0011271926341578364
# Similarity of British-stereotyped words to 'immigrant' before: 0.009861340746283531; similarity after: -0.0015505485935136676
#
# Similarity of Indian-stereotyped words to 'brown' before: 0.00312934466637671; similarity after: 0.002398422919213772
# Similarity of British-stereotyped words to 'brown' before: 0.030717017129063606; similarity after: 0.0017409748397767544
#
# Similarity of Indian-stereotyped words to 'poor' before: 0.0028579055797308683; similarity after: -0.0005144537426531315
# Similarity of British-stereotyped words to 'poor' before: 0.02466523088514805; similarity after: -0.000473601947305724

# %% [markdown]
# # The rest of the notebook hasn't been adapted for race.

# %% [markdown]
# ### Calcualte bias-by-clustering

# %%
def numerical_bias_by_clustering(model_before, model_after, masc_words, fem_words, k):
    
    scores_before, scores_after = [], []
    all_biased = masc_words.union(fem_words)
    
    for w in all_biased:
        
        most_similar_before = model_before.most_similar(w, topn = k)
        most_similar_before, _ = zip(*most_similar_before)

        most_similar_after = model_after.most_similar(w, topn = k)
        most_similar_after, _ = zip(*most_similar_after)
        
        neighbors_biased_before = len([w for w in most_similar_before if w in all_biased])
        neighbors_biased_after = len([w for w in most_similar_after if w in all_biased])
        scores_before.append(neighbors_biased_before)
        scores_after.append(neighbors_biased_after)
    print("avg. number of biased neighbors before: {}; after: {}".format(np.mean(scores_before), np.mean(scores_after)))

# %%
#numerical_bias_by_clustering(model, model_cleaned, set(masc_words), set(fem_words), k = 1000)

# %% [markdown]
# #### print the most similar words to random words before and after (to make sure we didn't damage the space too much)

# %%
from collections import defaultdict
import pickle

words_chosen = np.random.choice(words[:15000] , size = 40)
topn = 3
words_before_and_after = defaultdict(dict)
gendered_words_before_and_after = defaultdict(dict)

for w in words_chosen:
    words_and_sims_before = model.most_similar(w, topn = topn)
    words__and_sims_after = model_cleaned.most_similar(w, topn = topn)
    words_before, sims_before = zip(*words_and_sims_before)
    words_after, sims_after = zip(*words__and_sims_after)
    words_before_and_after[w]["before"] = words_before
    words_before_and_after[w]["after"] = words_after
    print("w: {}\n most-similar-before: {}\n most-similar-after: {}".format(w,words_before, words_after))
    print("----------------------------------")

print("====================================================================\n\n")
print("gendered words:")
words_chosen = ["miss", "mrs", "mr", "john", "rachel", "wife", "mom", "family", "father", "lady", "he", "she"]
words_chosen = ["ruth", "charlotte", "abigail", "sophie", "nichole", "emma", "olivia", "ava", "isabella", "sophia", "charlotte", "mia", "amelia",
                "james", "john", "robert", "michael", "william", "david", "richard", "joseph", "thomas", "ariel", "mike", "nurse", "mom", "secretary", "nursery"]
for w in words_chosen:
    
    words_and_sims_before = model.most_similar(w, topn = topn)
    words__and_sims_after = model_cleaned.most_similar(w, topn = topn)
    words_before, _ = zip(*words_and_sims_before)
    words_after, _ = zip(*words__and_sims_after)
    gendered_words_before_and_after[w]["before"] = words_before
    gendered_words_before_and_after[w]["after"] = words_after
    print("w: {}\n most-similar-before: {}\n most-similar-after: {}".format(w,words_before, words_after))
    print("----------------------------------")    
    
with open("words_before_and_after.pickle", "wb") as f:
    pickle.dump(words_before_and_after, f)
    
with open("words_before_and_after_gendered.pickle", "wb") as f:
    pickle.dump(gendered_words_before_and_after, f)
# Out:
# w: entrance
#  most-similar-before: ('entrances', 'gate', 'hallway')
#  most-similar-after: ('entrances', 'enterance', 'vestibule')
# ----------------------------------
# w: ornament
#  most-similar-before: ('ornaments', 'figurine', 'snowman')
#  most-similar-after: ('ornaments', 'snowman', 'figurine')
# ----------------------------------
# w: traits
#  most-similar-before: ('trait', 'qualities', 'characteristics')
#  most-similar-after: ('trait', 'qualities', 'characteristics')
# ----------------------------------
# w: criticize
#  most-similar-before: ('criticise', 'criticizing', 'condemn')
#  most-similar-after: ('criticise', 'criticizing', 'criticising')
# ----------------------------------
# w: bites
#  most-similar-before: ('bite', 'stings', 'bitten')
#  most-similar-after: ('bite', 'bitten', 'stings')
# ----------------------------------
# w: reports
#  most-similar-before: ('report', 'reported', 'reporting')
#  most-similar-after: ('report', 'reported', 'reporting')
# ----------------------------------
# w: shook
#  most-similar-before: ('shaking', 'smiled', 'nodded')
#  most-similar-after: ('shaking', 'shuddered', 'nodded')
# ----------------------------------
# w: gave
#  most-similar-before: ('took', 'had', 'giving')
#  most-similar-after: ('giving', 'took', 'came')
# ----------------------------------
# w: supervised
#  most-similar-before: ('supervision', 'supervise', 'supervising')
#  most-similar-after: ('supervision', 'supervise', 'supervising')
# ----------------------------------
# w: intern
#  most-similar-before: ('internship', 'interns', 'assistant')
#  most-similar-after: ('internship', 'interns', 'trainee')
# ----------------------------------
# w: cest
#  most-similar-before: ('cet', 'eest', 'cdt')
#  most-similar-after: ('cet', 'eest', 'bst')
# ----------------------------------
# w: separate
#  most-similar-before: ('seperate', 'two', 'multiple')
#  most-similar-after: ('seperate', 'separated', 'separately')
# ----------------------------------
# w: calculate
#  most-similar-before: ('calculating', 'calculated', 'calculation')
#  most-similar-after: ('calculating', 'calculates', 'calculated')
# ----------------------------------
# w: module
#  most-similar-before: ('modules', 'interface', 'configuration')
#  most-similar-after: ('modules', 'subsystem', 'interface')
# ----------------------------------
# w: sculpture
#  most-similar-before: ('sculptures', 'art', 'statue')
#  most-similar-after: ('sculptures', 'sculptural', 'sculptor')
# ----------------------------------
# w: seats
#  most-similar-before: ('seat', 'seating', 'steering')
#  most-similar-after: ('seat', 'seating', 'armrest')
# ----------------------------------
# w: odor
#  most-similar-before: ('odour', 'odors', 'smell')
#  most-similar-after: ('odour', 'odors', 'smell')
# ----------------------------------
# w: forwards
#  most-similar-before: ('forward', 'defensemen', 'backwards')
#  most-similar-after: ('forward', 'defensemen', 'defencemen')
# ----------------------------------
# w: dynasty
#  most-similar-before: ('dynasties', 'qing', 'ming')
#  most-similar-after: ('dynasties', 'qing', 'ming')
# ----------------------------------
# w: answers
#  most-similar-before: ('questions', 'answer', 'question')
#  most-similar-after: ('questions', 'answer', 'explanations')
# ----------------------------------
# w: djs
#  most-similar-before: ('dj', 'jockeys', 'entertainers')
#  most-similar-after: ('dj', 'jockeys', 'caterers')
# ----------------------------------
# w: textile
#  most-similar-before: ('textiles', 'garment', 'fabrics')
#  most-similar-after: ('textiles', 'garment', 'fabrics')
# ----------------------------------
# w: expands
#  most-similar-before: ('expand', 'expanding', 'expanded')
#  most-similar-after: ('broadens', 'expanding', 'expand')
# ----------------------------------
# w: distributed
#  most-similar-before: ('distribution', 'distribute', 'distributing')
#  most-similar-after: ('distribute', 'unevenly', 'heterogeneous')
# ----------------------------------
# w: thousand
#  most-similar-before: ('hundred', 'fifty', 'twenty')
#  most-similar-after: ('hundred', 'fifty', 'twenty')
# ----------------------------------
# w: adapter
#  most-similar-before: ('adaptor', 'adapters', 'connector')
#  most-similar-after: ('adaptor', 'adapters', 'plug')
# ----------------------------------
# w: cabinet
#  most-similar-before: ('cabinets', 'drawer', 'shelf')
#  most-similar-after: ('cabinets', 'drawer', 'sideboard')
# ----------------------------------
# w: uncertainty
#  most-similar-before: ('uncertainties', 'uncertain', 'ambiguity')
#  most-similar-after: ('uncertainties', 'unpredictability', 'imprecision')
# ----------------------------------
# w: lincoln
#  most-similar-before: ('jefferson', 'franklin', 'ford')
#  most-similar-after: ('mkz', 'mkx', 'towncar')
# ----------------------------------
# w: painful
#  most-similar-before: ('uncomfortable', 'pain', 'excruciating')
#  most-similar-after: ('painfull', 'excruciating', 'agonizing')
# ----------------------------------
# w: xvid
#  most-similar-before: ('dvdrip', 'brrip', 'avi')
#  most-similar-after: ('dvdrip', 'brrip', 'avi')
# ----------------------------------
# w: wisely
#  most-similar-before: ('judiciously', 'prudently', 'sensibly')
#  most-similar-after: ('judiciously', 'prudently', 'unwisely')
# ----------------------------------
# w: lieutenant
#  most-similar-before: ('colonel', 'sergeant', 'brigadier')
#  most-similar-after: ('sergeant', 'colonel', 'brigadier')
# ----------------------------------
# w: patron
#  most-similar-before: ('patrons', 'benefactor', 'honour')
#  most-similar-after: ('patrons', 'parishioner', 'benefactor')
# ----------------------------------
# w: scientists
#  most-similar-before: ('researchers', 'physicists', 'scientist')
#  most-similar-after: ('researchers', 'physicists', 'biologists')
# ----------------------------------
# w: warwick
#  most-similar-before: ('coventry', 'leamington', 'kenilworth')
#  most-similar-after: ('dionne', 'leamington', 'ri')
# ----------------------------------
# w: deficiency
#  most-similar-before: ('deficiencies', 'deficient', 'anemia')
#  most-similar-after: ('deficiencies', 'anemia', 'deficient')
# ----------------------------------
# w: chin
#  most-similar-before: ('forehead', 'cheek', 'cheeks')
#  most-similar-after: ('forehead', 'jawline', 'cheek')
# ----------------------------------
# w: rowbox
#  most-similar-before: ('fractionbox', 'superscriptbox', 'sqrtbox')
#  most-similar-after: ('fractionbox', 'superscriptbox', 'sqrtbox')
# ----------------------------------
# w: description
#  most-similar-before: ('summary', 'details', 'overview')
#  most-similar-after: ('descriptionthe', 'descriptions', 'descriptionthis')
# ----------------------------------
# ====================================================================
#
#
# gendered words:
# w: ruth
#  most-similar-before: ('helen', 'esther', 'margaret')
#  most-similar-after: ('esther', 'boaz', 'reichl')
# ----------------------------------
# w: charlotte
#  most-similar-before: ('raleigh', 'nc', 'atlanta')
#  most-similar-after: ('raleigh', 'nc', 'brontë')
# ----------------------------------
# w: abigail
#  most-similar-before: ('hannah', 'lydia', 'eliza')
#  most-similar-after: ('hannah', 'lydia', 'susannah')
# ----------------------------------
# w: sophie
#  most-similar-before: ('julia', 'marie', 'lucy')
#  most-similar-after: ('moone', 'madeline', 'claire')
# ----------------------------------
# w: nichole
#  most-similar-before: ('nicole', 'kimberly', 'kayla')
#  most-similar-after: ('nicole', 'kimberly', 'kayla')
# ----------------------------------
# w: emma
#  most-similar-before: ('emily', 'lucy', 'sarah')
#  most-similar-after: ('eliza', 'emily', 'sarah')
# ----------------------------------
# w: olivia
#  most-similar-before: ('emma', 'rachel', 'kate')
#  most-similar-after: ('munn', 'thirlby', 'natalia')
# ----------------------------------
# w: ava
#  most-similar-before: ('devine', 'zoe', 'isabella')
#  most-similar-after: ('devine', 'isabella', 'zoe')
# ----------------------------------
# w: isabella
#  most-similar-before: ('sophia', 'josephine', 'isabel')
#  most-similar-after: ('rossellini', 'ava', 'sophia')
# ----------------------------------
# w: sophia
#  most-similar-before: ('anna', 'lydia', 'julia')
#  most-similar-after: ('hagia', 'antipolis', 'isabella')
# ----------------------------------
# w: charlotte
#  most-similar-before: ('raleigh', 'nc', 'atlanta')
#  most-similar-after: ('raleigh', 'nc', 'brontë')
# ----------------------------------
# w: mia
#  most-similar-before: ('bella', 'mamma', 'mama')
#  most-similar-after: ('bangg', 'mamma', 'bella')
# ----------------------------------
# w: amelia
#  most-similar-before: ('earhart', 'louisa', 'caroline')
#  most-similar-after: ('earhart', 'fernandina', 'louisa')
# ----------------------------------
# w: james
#  most-similar-before: ('john', 'william', 'thomas')
#  most-similar-after: ('ellroy', 'blish', 'nightfire')
# ----------------------------------
# w: john
#  most-similar-before: ('james', 'william', 'paul')
#  most-similar-after: ('deere', 'scatman', 'galsworthy')
# ----------------------------------
# w: robert
#  most-similar-before: ('richard', 'william', 'james')
#  most-similar-after: ('pattinson', 'zemeckis', 'mccammon')
# ----------------------------------
# w: michael
#  most-similar-before: ('david', 'mike', 'brian')
#  most-similar-after: ('micheal', 'franti', 'moorcock')
# ----------------------------------
# w: william
#  most-similar-before: ('henry', 'edward', 'james')
#  most-similar-after: ('edward', 'henry', 'samuel')
# ----------------------------------
# w: david
#  most-similar-before: ('stephen', 'richard', 'michael')
#  most-similar-after: ('bisbal', 'lachapelle', 'magen')
# ----------------------------------
# w: richard
#  most-similar-before: ('robert', 'william', 'david')
#  most-similar-after: ('clayderman', 'rorty', 'gere')
# ----------------------------------
# w: joseph
#  most-similar-before: ('francis', 'charles', 'thomas')
#  most-similar-after: ('joesph', 'potiphar', 'beuys')
# ----------------------------------
# w: thomas
#  most-similar-before: ('james', 'william', 'john')
#  most-similar-after: ('theologica', 'szasz', 'aquinas')
# ----------------------------------
# w: ariel
#  most-similar-before: ('sharon', 'alexis', 'hanna')
#  most-similar-after: ('tiana', 'ehud', 'gaza')
# ----------------------------------
# w: mike
#  most-similar-before: ('brian', 'chris', 'dave')
#  most-similar-after: ('dave', 'birbiglia', 'ditka')
# ----------------------------------
# w: nurse
#  most-similar-before: ('nurses', 'nursing', 'physician')
#  most-similar-after: ('nurses', 'nursing', 'anesthetist')
# ----------------------------------
# w: mom
#  most-similar-before: ('dad', 'mother', 'mommy')
#  most-similar-after: ('dad', 'moms', 'mommy')
# ----------------------------------
# w: secretary
#  most-similar-before: ('deputy', 'minister', 'treasurer')
#  most-similar-after: ('secretaries', 'undersecretary', 'deputy')
# ----------------------------------
# w: nursery
#  most-similar-before: ('preschool', 'bedding', 'nurseries')
#  most-similar-after: ('nurseries', 'preschool', 'bedding')
# ----------------------------------

# %%
sims_before, sims_after
# Out:
# ((0.6873096227645874, 0.6871241331100464, 0.6773098707199097),
#  (0.5280705690383911, 0.5246070623397827, 0.5234867334365845))

# %% [markdown]
# ### bias by profession experiment

# %%
def get_bias_by_neighbors(model, model_cleaned, gendered_words, v, gender_direction): 
    
    neighbors = model_cleaned.similar_by_vector(v, topn=100) 
    neighbors_words = [n for n, _ in neighbors]
    
    #bias = len([n for n in neighbors_words if n in gendered_words])
    bias = len([n for n in neighbors_words if model.cosine_similarities(model[n], [gender_direction])[0] > 0])
    return bias

def bias_by_profession(model, model_cleaned, gender_direction, P, masc_words):
    
    with codecs.open("../data/lists/professions.json") as f:
        professions_and_scores = json.load(f)

    professions = [p[0] for p in professions_and_scores]
    #print(professions)
    professions = list(filter(lambda p: p in model, professions))
    vecs = np.array([model[p] for p in professions])
    vecs_cleaned = vecs.dot(P)
    bias_vals = np.array([model.cosine_similarities(gender_direction,vecs)])[0]
    #bias_vals_after = np.array([model.cosine_similarities(gender_direction,vecs_cleaned)])[0]
    bias_by_neighbors_after = np.array([get_bias_by_neighbors(model, model_cleaned, masc_words, v, gender_direction) for v in vecs_cleaned])
    bias_by_neighbors_before = np.array([get_bias_by_neighbors(model, model, masc_words, v, gender_direction) for v in vecs])

    #plt.ylim([np.min(bias_vals), np.max(bias_vals)])
    plt.plot(bias_vals, bias_by_neighbors_after, marker = "o", linestyle = "none", color = "red", label = "after", alpha = 0.25)
    plt.plot(bias_vals, bias_by_neighbors_before, marker = "o", linestyle = "none", color = "blue", label = "before", alpha = 0.25)
    
    word_idx_high = np.argsort(bias_vals)[:4] 
    word_idx_low = np.argsort(bias_vals)[-4:]
    word_idx_middle_low = np.argsort(bias_vals)[-55:-51]
    word_idx_middle_high = np.argsort(bias_vals)[51:55]
    words_biased_fem = [professions[i] for i in word_idx_high]
    words_biased_masc = [professions[i] for i in word_idx_low]
    mid_low = [professions[i] for i in word_idx_middle_low]
    mid_high = [professions[i] for i in word_idx_middle_high]
    words = words_biased_masc + words_biased_fem + mid_low + mid_high
    
    for w in words:
        i = professions.index(w)
        x1,y1 = bias_vals[i],bias_by_neighbors_after[i]
        plt.annotate(w , (x1,y1), size = 8, color = "red")
        x2,y2 = bias_vals[i],bias_by_neighbors_before[i]
        plt.annotate(w, (x2,y2), size = 8, color = "blue")
        #plt.arrow(x2,y2,x1-x2,y1-y2, width = 0.0005)
        
    plt.legend()
    plt.xlabel("bias-by-PROJECTION of the professions before")
    plt.ylabel("bias-by-NEIGHBORS")
    plt.title("projection bias before vs. neighbors bias before/after \n(# neighbors closer to 'she' then 'he')")
    plt.show()
    
    print("Correlation before: {}, p-value: {}".format(*pearsonr(bias_vals, bias_by_neighbors_before)))
    print("Correlation after: {}, p-value: {}".format(*pearsonr(bias_vals, bias_by_neighbors_after)))

# %%
bias_by_profession(model, model_cleaned, gender_direction, P, None)
# Out:
# Correlation before: 0.731901643307922, p-value: 4.576035795041354e-50
# Correlation after: 0.6990232037279748, p-value: 5.456280454020082e-44

# %%
vecs.shape
# Out:
# (150000, 300)

# %% [markdown]
# ### word association tests

# %%
# Auxiliary functions for experiments by Caliskan et al.

import scipy
import scipy.misc as misc
import itertools


def s_word(w, A, B, model, all_s_words):
    
    if w in all_s_words:
        return all_s_words[w]
    
    mean_a = []
    mean_b = []
    
    for a in A:
        mean_a.append(model.similarity(w,a))
    for b in B:
        mean_b.append(model.similarity(w,b))
        
    mean_a = sum(mean_a)/float(len(mean_a))
    mean_b = sum(mean_b)/float(len(mean_b))
    
    all_s_words[w] = mean_a - mean_b

    return all_s_words[w]


def s_group(X, Y, A, B, model, all_s_words):
    
    total = 0
    for x in X:
        x_sim = s_word(x, A, B, model, all_s_words)
        total += x_sim
    for y in Y:
        y_sim =  s_word(y, A, B, model, all_s_words)
        total -= y_sim
    
    #print(x_sim, y_sim)
        
    return total


def p_value_exhust(X, Y, A, B, model):
    
    if len(X) > 10:
        print ('might take too long, use sampled version: p_value')
        return
    
    assert(len(X) == len(Y))
    
    all_s_words = {}
    s_orig = s_group(X, Y, A, B, model, all_s_words)
    #print("s-orig: {}".format(s_orig))
    
    union = set(X+Y)
    subset_size = int(len(union)/2)
    
    larger = 0
    total = 0
    #all_subs = set(itertools.combinations(union, subset_size))
    #print(all_subs)
    for subset in tqdm.tqdm_notebook(set(itertools.combinations(union, subset_size))):
        total += 1
        Xi = list(set(subset))
        Yi = list(union - set(subset))
        if s_group(Xi, Yi, A, B, model, all_s_words) > s_orig:
            larger += 1
    #print ('num of samples', total)
    return larger/float(total)


def p_value_sample(X, Y, A, B, model):
    
    random.seed(10)
    np.random.seed(10)
    all_s_words = {}
    
    assert(len(X) == len(Y))
    length = len(X)
    
    s_orig = s_group(X, Y, A, B, model, all_s_words) 
    
    num_of_samples = min(10000, int(scipy.special.comb(length*2,length)*100))
    print ('num of samples', num_of_samples)
    larger = 0
    for i in range(num_of_samples):
        permute = np.random.permutation(X+Y)
        Xi = permute[:length]
        Yi = permute[length:]
        if s_group(Xi, Yi, A, B, model, all_s_words) > s_orig:
            larger += 1
    
    return larger/float(num_of_samples)

# %%
# Experiment 1

A = ['john', 'paul', 'mike', 'kevin', 'steve', 'greg', 'jeff', 'bill']
B = ['amy', 'joan', 'lisa', 'sarah', 'diana', 'kate', 'ann', 'donna']

C = ['executive', 'management', 'professional', 'corporation', 'salary', 'office', 'business', 'career']
D = ['home', 'parents', 'children', 'family', 'cousins', 'marriage', 'wedding', 'relatives']

print (p_value_exhust(A, B, C, D, model_cleaned))

# Experiment 2

E = ['math', 'algebra', 'geometry', 'calculus', 'equations', 'computation', 'numbers', 'addition']
F = ['poetry', 'art', 'dance', 'literature', 'novel', 'symphony', 'drama', 'sculpture']

print (p_value_exhust(A, B, E, F, model_cleaned))


# Experiment 3

G = ['science', 'technology', 'physics', 'chemistry', 'einstein', 'nasa', 'experiment', 'astronomy']
H = ['poetry', 'art', 'shakespeare', 'dance', 'literature', 'novel', 'symphony', 'drama']

print (p_value_exhust(A, B, G, H, model_cleaned))
# Out:
# /tmp/ipykernel_51056/280116927.py:63: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for subset in tqdm.tqdm_notebook(set(itertools.combinations(union, subset_size))):
#   0%|          | 0/12870 [00:00<?, ?it/s]
# 0.0016317016317016317
#   0%|          | 0/12870 [00:00<?, ?it/s]
# 0.017871017871017872
#   0%|          | 0/12870 [00:00<?, ?it/s]
# 0.09976689976689977

# %% [markdown]
# ### Compare with debiasing on specific directions

# %%
#specific_words = [("he", "she"), ("man", "woman"), ("boy", "girl"), ("him", "her"), ("father", "mother"), ("king", "queen")]
specific_words = ["woman", "man"], ["girl", "boy"], ["she", "he"], ["mother", "father"], ["daughter", "son"], ["gal", "guy"], ["female", "male"], ["her", "his"], ["herself", "himself"], ["mary", "john"]

# %%
vecs_specific_words = np.array([ [model[p[1]] - model[p[0]]] for p in specific_words])
P_by_words = debias.debias_by_specific_directions(vecs_specific_words, 300) # projection matrix generated by zeroing the above directions
X_dev_cleaned = (P_by_words.dot(X_dev.T)).T
X_train_cleaned = (P_by_words.dot(X_train.T)).T

# %%
clf = LinearSVC(dual = False)
clf.fit(X_train_cleaned, Y_train)
print(clf.score(X_dev_cleaned, Y_dev))
# Out:
# 1.0

# %%
P, rowspace_projs, Ws = debias.get_debiasing_projection(gender_clf, params, len(specific_words), 300, is_autoregressive, min_acc,
                                    X_train, Y_train, X_dev, Y_dev,
                                       Y_train_main=None, Y_dev_main=None, 
                                        by_class = False, dropout_rate = dropout_rate)

clf = LinearSVC(dual = False)
clf.fit(P.dot(X_train.T).T, Y_train)
print(clf.score(P.dot(X_test.T).T, Y_test))
# Out:
# iteration: 9, accuracy: 0.5070599309695638: 100%|████| 10/10 [00:07<00:00,  1.30it/s]
# 0.5717783218339639

# %% [markdown]
# #### PCA (not in the paper)

# %%
""" 
gender_vecs = [model[p[0]] - model[p[1]] for p in specific_words]
pca = PCA(n_components=1)
pca.fit(gender_vecs)
gender_direction = pca.components_
P_by_words_pca = debias.debias_by_specific_directions(np.array([gender_direction]), 300) # projection matrix generated by zeroing the above directions
X_dev_cleaned_pca = (P_by_words_pca.dot(X_dev.T)).T
X_train_cleaned_pca = (P_by_words_pca.dot(X_train.T)).T
"""
# Out:
# ' \ngender_vecs = [model[p[0]] - model[p[1]] for p in specific_words]\npca = PCA(n_components=1)\npca.fit(gender_vecs)\ngender_direction = pca.components_\nP_by_words_pca = debias.debias_by_specific_directions(np.array([gender_direction]), 300) # projection matrix generated by zeroing the above directions\nX_dev_cleaned_pca = (P_by_words_pca.dot(X_dev.T)).T\nX_train_cleaned_pca = (P_by_words_pca.dot(X_train.T)).T\n'

# %%
"""
clf = LinearSVC(dual = False)
clf.fit(X_train_cleaned_pca, Y_train)
print(clf.score(X_dev_cleaned_pca, Y_dev))
"""
# Out:
# '\nclf = LinearSVC(dual = False)\nclf.fit(X_train_cleaned_pca, Y_train)\nprint(clf.score(X_dev_cleaned_pca, Y_dev))\n'

# %% [markdown]
# A linear classifier is still able to recover the gender with non-random accuracy.

# %%
"""
M =  2000

#tsne_before = tsne_by_gender(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M], title = "Original")
X_dev_cleaned = (P_by_words.dot(X_dev.T)).T #X_dev.dot(P)
X_test_cleaned = (P_by_words.dot(X_test.T)).T #X_test.dot(P)
X_trained_cleaned = (P_by_words.dot(X_train.T)).T #X_train.dot(P)
all_significantly_biased_cleaned = P_by_words.dot(all_significantly_biased_vecs.T).T

tsne_after = tsne_by_gender(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M], title = "Projected (t = {})".format(n))
print("V-measure-before (original space): {}".format(compute_v_measure(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M])))
print("V-measure-after (original space): {}".format(compute_v_measure(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M])))
"""
# Out:
# '\nM =  2000\n\n#tsne_before = tsne_by_gender(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M], title = "Original")\nX_dev_cleaned = (P_by_words.dot(X_dev.T)).T #X_dev.dot(P)\nX_test_cleaned = (P_by_words.dot(X_test.T)).T #X_test.dot(P)\nX_trained_cleaned = (P_by_words.dot(X_train.T)).T #X_train.dot(P)\nall_significantly_biased_cleaned = P_by_words.dot(all_significantly_biased_vecs.T).T\n\ntsne_after = tsne_by_gender(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M], title = "Projected (t = {})".format(n))\nprint("V-measure-before (original space): {}".format(compute_v_measure(all_significantly_biased_vecs[:M], all_significantly_biased_labels[:M])))\nprint("V-measure-after (original space): {}".format(compute_v_measure(all_significantly_biased_cleaned[:M], all_significantly_biased_labels[:M])))\n'

# %%
model, model_cleaned
# Out:
# (<gensim.models.keyedvectors.Word2VecKeyedVectors at 0x10497b310>,
#  <gensim.models.keyedvectors.Word2VecKeyedVectors at 0x15fcefb80>)

# %%
w = "nurse"
w2 = "doctor"
v_w_before, v_w_after = model[w], model_cleaned[w]
v_w2_before, v_w2_after = model[w2], model_cleaned[w2]

# %%
np.linalg.norm(v_w_before-v_w2_before)
# Out:
# 6.3952494

# %%
np.linalg.norm(v_w_after-v_w2_after)
# Out:
# 5.5972257
